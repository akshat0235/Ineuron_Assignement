# %% [markdown]
# ### 1 Question

# %%
 # To avoid repetition of code , To increase code readbility

# %% [markdown]
# ### 2 Question

# %%
# function runs when it is called

# %% [markdown]
# ### 3 question

# %%
# def function_name():
        ....
        ....

# %% [markdown]
# ### 4 Question

# %%
# function is a piece of code that can be used agian and again 
# function call is used to run that function that is defined by user

# %% [markdown]
# ### 5 Question

# %%
# it depends upon user global scope can be used in whole program
# where as local scope is only used in inside a function

# %% [markdown]
# ### 6 Question

# %%
# when function calls return local scope variable  is destroyed
# as function use is completed

# %% [markdown]
# ### 7 Question

# %%
# return statment is used to complete function task mainly and
# used as the last statement in a function , YES

# %% [markdown]
# ### 8 Question

# %%
# default return value will be always None if return statement is nothing

# %% [markdown]
# ### 9 Question

# %%
# by using global keyword before a variable

# %% [markdown]
# ### 10 Question

# %%
# none is the data type of its own NoneType

# %% [markdown]
# ### 11 Question

# %%
# this will import module named as areallyourpetsnamederic

# %% [markdown]
# ### 12 Quesiton

# %%
# from spam import bacon

# %% [markdown]
# ### 13 Question

# %%
# Exception handling can be used

# %% [markdown]
# ### 14 Question

# %%
# both try and except are bultin keyword in python and used in 
# exception handling.

# try caluse lets a user to test a block of code for errors
# expect clause lets a user to handle errors
