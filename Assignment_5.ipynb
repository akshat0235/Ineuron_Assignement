# %% [markdown]
# ### 1 question

# %%
d={}

# %% [markdown]
# ### 2 Question

# %%
d={'foo:42'}

# value 42

# %% [markdown]
# ### 3 Question

# %%
# dict holds data in the from of key-value pair and represented by {}
# list holds all types of data and represented by []
#lists are mutable but dict are not

# %% [markdown]
# ### 4 question

# %%
spam={'bar':100}

# key error as 'foo' doesnt exsist here

# %% [markdown]
# ### 5 Question

# %%
# both will return True 'cat' and 'cat' in spam.keys() because
# 'cat' is key here

# %% [markdown]
# ### 6 Question

# %%
# 1st one will return True but spam.values() will return as 'cat'
# is key not value , spam.values() will return values not keys

# %% [markdown]
# ### 7 Question

# %%
spam.setdefault('color','black')
# Out:
# 'black'

# %% [markdown]
# ### 8 question

# %%
# import pprint
# pprint.pprint()
