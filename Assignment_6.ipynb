# %% [markdown]
# ### 1 Question

# %%
# to insert an illegal character in a string these are used example / /n etc.

# %%
s="My name is "akshat "sharma "
# Out:
#   File "<ipython-input-5-e0676bf13e6d>", line 1
#     s="My name is "akshat "sharma "
#                    ^
# SyntaxError: invalid syntax

# %%
# to avoid this type of error escape characters are used

s="My name is \"akshat\" sharma "

# %%
s
# Out:
# 'My name is "akshat" sharma '

# %% [markdown]
# ### 2 question

# %%
# n for new line and t for tab

# %% [markdown]
# ### 3 question

# %%
s="My name is \"akshat\" sharma "

# %% [markdown]
# ### 4 Question

# %%
# because ' quote is in between " " quotes to it won't throw an error

# %% [markdown]
# ### 5 Question

# %%
# print('akshat')
# print('enrolled in ineuron')
# this can be done

# %% [markdown]
# ### 6 question

# %%
'Hello, world!'[1] # because str supports indexing so it will grab
                   # value of index 1
# Out:
# 'e'

# %%
'Hello, world!'[0:5] # this is slicing operation will start from
                     # 0 index and go till 5 but 5 is not included
                     # as it is upperbond
# Out:
# 'Hello'

# %%
'Hello, world!'[:5] # same as above
# Out:
# 'Hello'

# %%
'Hello, world!'[3:] # will start from 3rd index go till end as
# no upper or end index is specified
# Out:
# 'lo, world!'

# %% [markdown]
# ### 7 question

# %%
'Hello'.upper() # built-in method of converting a str to upper case
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper() # 1st it will convert the whole str to 

# to Uppper and than check for upper and return the result in 
# the form of True and False
# Out:
# True

# %%
'Hello'.upper().lower() # 1st converted to upper then lower
# Out:
# 'hello'

# %% [markdown]
# ### 8 Question

# %%
'Remember, remember, the fifth of July.'.split()
# buil-in method will convert to list and values are taken as spaces and words/characters
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# built-in str method to concat list and return to single line 
# stirng
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ### 9 Question

# %%
# .ljust(),.rjust() and .center()

# %% [markdown]
# ### 10 Question

# %%
# strip() methid
