# %% [markdown]
# ### 1 Ques

# %% [raw]
# * is expression
# 'hello' this is  a value
# -87.8 this is a value
# - this is a expresion
# / this is a expression
# + this is a expression
# 6 this is value

# %% [markdown]
# ### 2 Ques

# %% [raw]
# variables are reserved memory loactions where
# as string is a data type
# example
#
# a = 10 var
# 'Akshat' str

# %% [markdown]
# ### 3 Ques

# %% [raw]
# 3 different data types are
#
#  int-(1,2,-3....)
#  float-(0.3,0.4,...)
#  complex-(5+4i,.....)

# %% [markdown]
# ### 4 ques

# %% [raw]
# Exp is made of some sort of mathematical operations
# to perform some mathematical task like sum,sub etc.

# %% [markdown]
# ### 6 ques

# %%
bacon = 22
"""
due to assignment operator bacon contains 20
"""

# %%
bacon+1
"""
only perfroms math operations but for var
bacon it would still remain 22 as here we dont
have used assignment operator 
"""
# Out:
# 23

# %%
bacon # as here this can bee seen
# Out:
# 22

# %% [markdown]
# ### 7 ques

# %%
'spam'+'spmaspam'
# Out:
# 'spamspmaspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %% [raw]
# both will yeild same result as we are using
# string method of concatination and multiplication

# %% [markdown]
# ### 8 ques

# %%
# because var names can't be a number like 100

# %% [markdown]
# ### 9 ques

# %%
# int(),str() and float()

# %% [markdown]
# ### 10 ques

# %% [raw]
# because 99 is of int type and rest are of str type
#
# it can be fixed by converting 99 to str
# like '99' this will concat the 3 strings
